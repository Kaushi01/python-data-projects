# %%
import pandas as pd 


data= pd.read_csv(r'D:\Hungry Coders\database popularity\database_popularity_dataset.csv')


print(data)
# Out:
#        respondent_id database_used         context
# 0                  1    PostgreSQL         Web App
# 1                  2         MySQL       Analytics
# 2                  3        SQLite       Analytics
# 3                  4         MySQL       Analytics
# 4                  5        SQLite         Web App
# ...              ...           ...             ...
# 86995          86996       MariaDB  Enterprise App
# 86996          86997    PostgreSQL       Dashboard
# 86997          86998    PostgreSQL       Analytics
# 86998          86999       MariaDB  Enterprise App
# 86999          87000        Oracle       Analytics
#
# [87000 rows x 3 columns]

# %%
# Strip any leading/trailing whitespace from all column names
data.columns = data.columns.str.strip()

# Plot a bar chart for the second column (database_used)
data['database_used'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='database_used'>
