# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
import matplotlib.pyplot  as plt
import pandas as pd
import numpy as np

df= pd.read_csv(r"D:\Hungry Coders\Matplotlib\Mental_Health_and_Social_Media_Balance_Dataset.csv")
df.head()
# Out:
#   User_ID  Age  Gender  Daily_Screen_Time(hrs)  Sleep_Quality(1-10)  \
# 0    U001   44    Male                     3.1                  7.0
# 1    U002   30   Other                     5.1                  7.0
# 2    U003   23   Other                     7.4                  6.0
# 3    U004   36  Female                     5.7                  7.0
# 4    U005   34  Female                     7.0                  4.0
#
#    Stress_Level(1-10)  Days_Without_Social_Media  Exercise_Frequency(week)  \
# 0                 6.0                        2.0                       5.0
# 1                 8.0                        5.0                       3.0
# 2                 7.0                        1.0                       3.0
# 3                 8.0                        1.0                       1.0
# 4                 7.0                        5.0                       1.0
#
#   Social_Media_Platform  Happiness_Index(1-10)
# 0              Facebook                   10.0
# ...

# %%
df["Gender"]
df.head()
# Out:
#   User_ID  Age  Gender  Daily_Screen_Time(hrs)  Sleep_Quality(1-10)  \
# 0    U001   44    Male                     3.1                  7.0
# 1    U002   30   Other                     5.1                  7.0
# 2    U003   23   Other                     7.4                  6.0
# 3    U004   36  Female                     5.7                  7.0
# 4    U005   34  Female                     7.0                  4.0
#
#    Stress_Level(1-10)  Days_Without_Social_Media  Exercise_Frequency(week)  \
# 0                 6.0                        2.0                       5.0
# 1                 8.0                        5.0                       3.0
# 2                 7.0                        1.0                       3.0
# 3                 8.0                        1.0                       1.0
# 4                 7.0                        5.0                       1.0
#
#   Social_Media_Platform  Happiness_Index(1-10)
# 0              Facebook                   10.0
# ...

# %%
sns.lineplot(x= "Age", y= "Days_Without_Social_Media", data= df, hue= "Gender", ci= None)
plt.title("Social media avoidance Vs Age")
plt.show()
# Out:
# C:\Users\raj\AppData\Local\Temp\ipykernel_17476\3820877838.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x= "Age", y= "Days_Without_Social_Media", data= df, hue= "Gender", ci= None)
